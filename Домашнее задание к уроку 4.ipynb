# %% [markdown]
# ###Задание №1

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# %config Inline.Backend.figure_format = 'svg'

# %%
x = [1, 2, 3, 4, 5, 6, 7]

# %%
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

# %%
plt.plot[x,y]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c2e26510ac78> in <module>
# ----> 1 plt.plot[x,y]
#
# TypeError: 'function' object is not subscriptable

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %% [markdown]
# # Задание №2

# %%
t = np.linspace(0, 10, 51)

# %%
f= np.cos(t)

# %%
plt.plot(t, f, color='green')

# %%
plt.title('График F(t)')
# Out:
# Text(0.5, 1.0, 'График F(t)')

# %%
plt.xlabel('Значение t')
# Out:
# Text(0.5, 0, 'Значение t')

# %%
plt.ylabel('Значение f')
# Out:
# Text(0, 0.5, 'Значение f')

# %%
plt.axis([0.5, 9.5, -2.5, 2.5])
# Out:
# (0.5, 9.5, -2.5, 2.5)

# %%
plt.plot(t, f, color='green')
plt.title('График F(t)')
plt.xlabel('Значение t')
plt.ylabel('Значение f')
plt.axis([0.5, 9.5, -2.5, 2.5])
# Out:
# (0.5, 9.5, -2.5, 2.5)

# %% [markdown]
# ### Задание №3

# %%
x = np.linspace(-3, 3, 51)

# %%
y1 = x**2

# %%
y2 = 2 * x + 0.5

# %%
y3 = -3 * x - 1.5

# %%
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.plot(x, y1)
ax2.plot(x, y2)
ax3.plot(x, y3)
ax4.plot(x, y4)
ax1.set_title('График y_1')
ax2.set_title('График y_2')
ax3.set_title('График y_3')
ax4.set_title('График y_4')
ax1.set_xlim([-5, 5])
fig.set_size_inches(8, 6)
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# # Задание №4

# %%
import pandas as pd

# %%
creditcard = pd.read_csv(r'C:\creditcard.csv')

# %%
plt.style.use('fivethirtyeight')

# %%
class_list = creditcard['Class'].value_counts()

# %%
class_list.plot(kind='barh')

# %%
class_list.plot(kind='barh', logx=True)

# %%
class0 = creditcard.loc[creditcard['Class'] == 0, ['V1']]
class1 = creditcard.loc[creditcard['Class'] == 1, ['V1']]

# %%
plt.hist(class0['V1'], bins=20, density=True, alpha=0.5, label='Class 0', color='grey')
plt.hist(class1['V1'], bins=20, density=True, alpha=0.5, label='Class 1', color='red')
plt.legend()
